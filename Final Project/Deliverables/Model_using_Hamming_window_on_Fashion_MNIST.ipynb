# %%
# -*- coding: utf-8 -*-
import math
import torch
from torch.nn.parameter import Parameter
import torch.nn.functional as F
import torch.nn.init as init
from torch.nn.modules.utils import _pair
from torch.nn.modules.module import Module
import numpy as np

def window_with_hamming(weight):
    N=weight.shape[-1]
    w=np.hamming(N)
    w_2d=torch.tensor(np.outer(w,w)).type(torch.cuda.FloatTensor)
    return weight*w_2d # broadcasting
def window_with_blackman(weight):
    N=weight.shape[-1]
    w=np.blackman(N)
    w_2d=torch.tensor(np.outer(w,w)).type(torch.cuda.FloatTensor)
    return weight*w_2d # broadcasting
def window_with_kaiser(weight):
    N=weight.shape[-1]
    w=np.kaiser(N,14)
    w_2d=torch.tensor(np.outer(w,w)).type(torch.cuda.FloatTensor)
    return weight*w_2d # broadcasting

class _ConvNd(Module):

    __constants__ = ['stride', 'padding', 'dilation', 'groups', 'bias',
                     'padding_mode', 'output_padding', 'in_channels',
                     'out_channels', 'kernel_size']

    def __init__(self, in_channels, out_channels, kernel_size, stride,
                 padding, dilation, transposed, output_padding,
                 groups, bias, padding_mode):
        super(_ConvNd, self).__init__()
        if in_channels % groups != 0:
            raise ValueError('in_channels must be divisible by groups')
        if out_channels % groups != 0:
            raise ValueError('out_channels must be divisible by groups')
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        self.dilation = dilation
        self.transposed = transposed
        self.output_padding = output_padding
        self.groups = groups
        self.padding_mode = padding_mode
        if transposed:
            self.weight = Parameter(torch.Tensor(
                in_channels, out_channels // groups, *kernel_size))
        else:
            self.weight = Parameter(torch.Tensor(
                out_channels, in_channels // groups, *kernel_size))
        if bias:
            self.bias = Parameter(torch.Tensor(out_channels))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        if self.bias is not None:
            fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
            bound = 1 / math.sqrt(fan_in)
            init.uniform_(self.bias, -bound, bound)

    def extra_repr(self):
        s = ('{in_channels}, {out_channels}, kernel_size={kernel_size}'
             ', stride={stride}')
        if self.padding != (0,) * len(self.padding):
            s += ', padding={padding}'
        if self.dilation != (1,) * len(self.dilation):
            s += ', dilation={dilation}'
        if self.output_padding != (0,) * len(self.output_padding):
            s += ', output_padding={output_padding}'
        if self.groups != 1:
            s += ', groups={groups}'
        if self.bias is None:
            s += ', bias=False'
        return s.format(**self.__dict__)

    def __setstate__(self, state):
        super(_ConvNd, self).__setstate__(state)
        if not hasattr(self, 'padding_mode'):
            self.padding_mode = 'zeros'
#%%
class Conv2d_window(_ConvNd):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0, dilation=1, groups=1,
                 bias=True, padding_mode='zeros'):
        kernel_size = _pair(kernel_size)
        stride = _pair(stride)
        padding = _pair(padding)
        dilation = _pair(dilation)
        super(Conv2d_window, self).__init__(
            in_channels, out_channels, kernel_size, stride, padding, dilation,
            False, _pair(0), groups, bias, padding_mode)

    def conv2d_forward(self, input, weight):
        weight=window_with_hamming(weight)
        if self.padding_mode == 'circular':
            expanded_padding = ((self.padding[1] + 1) // 2, self.padding[1] // 2,
                                (self.padding[0] + 1) // 2, self.padding[0] // 2)
            return F.conv2d(F.pad(input, expanded_padding, mode='circular'),
                            weight, self.bias, self.stride,
                            _pair(0), self.dilation, self.groups)
        return F.conv2d(input, weight, self.bias, self.stride,
                        self.padding, self.dilation, self.groups)

    def forward(self, input):
        return self.conv2d_forward(input, self.weight)

# %%
# -*- coding: utf-8 -*-

import os
import warnings


import numpy as np
from torchvision import datasets, transforms
#from windowed_conv import Conv2d_window
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
#-----------------------------------------------------------------------------------------------
"""import argparse

parser = argparse.ArgumentParser(description='CIFAR100 training with 7x7 window in all layers and weight decay')
parser.add_argument('--seed', default=None, type=int, help='rng seed')
parser.add_argument('--n_layers', default=6, type=int, help='total number of conv layers')
parser.add_argument('--save', type=str, default='/save_dir')

args = parser.parse_args()"""

# Fix seed
"""if args.seed is not None:
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    warnings.warn('You have chosen to seed training. '
                  'This will turn on the CUDNN deterministic setting, '
                  'which can slow down your training considerably! '
                  'You may see unexpected behavior when restarting '
                  'from checkpoints.')"""
#-----------------------------------------------------------------------------------------------
# Other useful definitions
class Flatten(nn.Module):
    def __init__(self):
        super(Flatten, self).__init__()
    def forward(self, x):
        shape=torch.prod(torch.tensor(x.shape[1:])).item()
        return x.reshape(-1,shape) # batchsize-by-rest

def makedirs(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)

makedirs("/save_dir")

CELoss=nn.CrossEntropyLoss()
device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#-----------------------------------------------------------------------------------------------
# Define CIFAR100 dataloaders
transform_train = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomCrop(32, padding=4),
                                      transforms.ToTensor()])
transform_test=transforms.Compose([transforms.ToTensor()])
data_path='/path_to_Fashion'
batch_size=64
print("Batch_size: ", batch_size)

# Training data
#cifar100_trainset=datasets.CIFAR100(root=data_path, train=True, transform=transform_train, download=True)
#MNIST_trainset = datasets.MNIST(root=data_path, train=True, transform=transform_train, download=True)
Fashion_MNIST_trainset = datasets.FashionMNIST(root=data_path, train=True, transform=transform_train, download=True)
#train_dl=torch.utils.data.DataLoader(cifar100_trainset, batch_size=batch_size, shuffle=True, num_workers=2)
#train_dl=torch.utils.data.DataLoader(MNIST_trainset, batch_size=batch_size, shuffle=True, num_workers=2)
train_dl=torch.utils.data.DataLoader(Fashion_MNIST_trainset, batch_size=batch_size, shuffle=True, num_workers=2)

# Validation data
#cifar100_testset=datasets.CIFAR100(root=data_path, train=False, transform=transform_test, download=True)
#MNIST_testset=datasets.MNIST(root=data_path, train=False, transform=transform_test, download=True)
Fashion_MNIST_testset=datasets.FashionMNIST(root=data_path, train=False, transform=transform_test, download=True)
#test_dl=torch.utils.data.DataLoader(cifar100_testset, batch_size=batch_size, shuffle=False, num_workers=2)
#test_dl=torch.utils.data.DataLoader(MNIST_testset, batch_size=batch_size, shuffle=False, num_workers=2)
test_dl=torch.utils.data.DataLoader(Fashion_MNIST_testset, batch_size=batch_size, shuffle=False, num_workers=2)
#-----------------------------------------------------------------------------------------------
# Define the 2 models
#n_inp_ch=3 # CIFAR100
n_inp_ch=1 # MNIST
n_out_ch=128
n_out2_ch=256
n_classes=100 # CIFAR100
n_classes=10 # MNIST

# Define networks
n_layers=6

block=[]
block.append(torch.nn.Conv2d(n_inp_ch,n_out_ch,kernel_size=(7,7),stride=2,padding=(3,3),bias=False))
block.append(torch.nn.BatchNorm2d(n_out_ch))
block.append(torch.nn.ReLU())
block.append(torch.nn.Conv2d(n_out_ch,n_out2_ch,kernel_size=(7,7),padding=(3,3),bias=False))
block.append(torch.nn.BatchNorm2d(n_out2_ch))
block.append(torch.nn.ReLU())

block_win=[]
block_win.append(Conv2d_window(n_inp_ch,n_out_ch,kernel_size=(7,7),stride=2,padding=(3,3),bias=False))
block_win.append(torch.nn.BatchNorm2d(n_out_ch))
block_win.append(torch.nn.ReLU())
block_win.append(Conv2d_window(n_out_ch,n_out2_ch,kernel_size=(7,7),padding=(3,3),bias=False))
block_win.append(torch.nn.BatchNorm2d(n_out2_ch))
block_win.append(torch.nn.ReLU())

if n_layers>2:
    for i in range(n_layers-2):
        block.append(torch.nn.Conv2d(n_out2_ch,n_out2_ch,kernel_size=(7,7),padding=(3,3),bias=False))
        block.append(torch.nn.BatchNorm2d(n_out2_ch))
        block.append(torch.nn.ReLU())

        block_win.append(Conv2d_window(n_out2_ch,n_out2_ch,kernel_size=(7,7),padding=(3,3),bias=False))
        block_win.append(torch.nn.BatchNorm2d(n_out2_ch))
        block_win.append(torch.nn.ReLU())

model=torch.nn.Sequential(*block,torch.nn.AdaptiveAvgPool2d((1,1)),\
               Flatten(),torch.nn.Linear(n_out2_ch,n_classes)).to(device)

model_win=torch.nn.Sequential(*block_win,torch.nn.AdaptiveAvgPool2d((1,1)),\
               Flatten(),torch.nn.Linear(n_out2_ch,n_classes)).to(device)

if n_layers>13:
    warnings.warn("Networks deeper than 13 layers may not be ideal for small image sizes "+\
             +"(e.g. 32 x 32) and with the current width/pooling specifications")
#-----------------------------------------------------------------------------------------------
# Define optimizer
optim=torch.optim.SGD(model.parameters(),lr=0.01,momentum=0.9, weight_decay=0.001)
optim_win=torch.optim.SGD(model_win.parameters(),lr=0.01,momentum=0.9, weight_decay=0.001)
#-----------------------------------------------------------------------------------------------
# Training
loss_counter=0
log_loss=50 # track loss every 20 batches
n_epoch=50
#n_train_img=len(CIFAR10_trainset)
#n_train_img=len(MNIST_trainset)
n_train_img=len(Fashion_MNIST_trainset)

plot_loss=np.zeros(n_epoch*int(np.floor(np.ceil(n_train_img/batch_size)/log_loss)))
plot_loss_win=np.zeros(n_epoch*int(np.floor(np.ceil(n_train_img/batch_size)/log_loss)))

print("Totle number of Epochs:", n_epoch)

for i_epoch in range(n_epoch):
    print("Epoch: ", i_epoch)
    batch_counter=0
    running_loss=0
    running_loss_win=0

    # Learning rate decay
    if i_epoch==75 or i_epoch==120:
        for param_group in optim.param_groups:
            param_group['lr']=0.1*param_group['lr']
        for param_group in optim_win.param_groups:
            param_group['lr']=0.1*param_group['lr']

    for X,y in train_dl:
        batch_counter+=1
        # Train
        X=X.to(device)
        y=y.to(device)

        # Backprop model 1
        optim.zero_grad()
        pred=model(X)
        loss=CELoss(pred,y)
        loss.backward()
        optim.step()

        # Backprop model 2
        optim_win.zero_grad()
        pred_win=model_win(X)
        loss_win=CELoss(pred_win,y)
        loss_win.backward()
        optim_win.step()

        running_loss+=loss.item()
        running_loss_win+=loss_win.item()

        if batch_counter%log_loss==0:
            # print things
            print("Batch_Counter: ", batch_counter)
            print(np.argmax(pred[0,:].detach().cpu().numpy()),\
                  np.argmax(pred_win[0,:].detach().cpu().numpy()),\
                  y[0].detach().cpu().numpy())

            # update loss trace
            plot_loss[loss_counter]=running_loss
            print("Running loss: ", running_loss)
            plot_loss_win[loss_counter]=running_loss_win
            print("Running loss windowed: ", running_loss_win)
            loss_counter+=1

            running_loss=0
            running_loss_win=0

# Plot losses
plt.figure(1)
plt.plot(plot_loss,label='conv')
plt.plot(plot_loss_win,label='conv_win')
plt.title('Losses')
plt.ylabel('Loss')
plt.legend()
plt.savefig(os.path.join("/save_dir", 'loss_cifar100_all_win_wd_'+str(n_layers)+'_layers_'+str(None)+'.pdf'), bbox_inches='tight')

# Plot losses zoomed in
plt.figure(2)
plt.plot(plot_loss[-100:],label='conv')
plt.plot(plot_loss_win[-100:],label='conv_win')
plt.title('Zoomed Losses')
plt.ylabel('Loss')
plt.legend()
plt.savefig(os.path.join("/save_dir", 'loss_zoom_cifar100_all_win_wd_'+str(n_layers)+'_layers_'+str(None)+'.pdf'), bbox_inches='tight')
#-----------------------------------------------------------------------------------------------
# Validation
accuracy=np.zeros(n_classes)
accuracy_win=np.zeros(n_classes)
class_counter=np.zeros(n_classes)

loss_counter=0
log_loss=20 # track loss every 20 batches
#n_test_img=len(cifar100_testset)
n_test_img=len(Fashion_MNIST_testset)

plot_val_loss=np.zeros(int(np.floor(np.ceil(n_test_img/batch_size)/log_loss)))
plot_val_loss_win=np.zeros(int(np.floor(np.ceil(n_test_img/batch_size)/log_loss)))

print('Validating...')

batch_counter=0
running_loss=0
running_loss_win=0

with torch.no_grad():
    model.eval()
    model_win.eval()

    for X,y in test_dl:
        # Test
        batch_counter+=1
        X=X.to(device)

        pred=model(X)
        pred_win=model_win(X)

        loss=CELoss(pred,y.to(device))
        loss_win=CELoss(pred_win,y.to(device))
        running_loss+=loss.item()
        running_loss_win+=loss_win.item()

        # Get accuracy
        for j in range(int(y.shape[0])):
            i_class=y[j].detach().numpy().item()

            class_counter[i_class]+=1
            accuracy[i_class]+=(i_class==np.argmax(pred[j,:].detach().cpu().numpy()))
            accuracy_win[i_class]+=(i_class==np.argmax(pred_win[j,:].detach().cpu().numpy()))

        if batch_counter%log_loss==0:
            # print things
            print("Batch_Counter: ", batch_counter)

            # update loss trace
            plot_val_loss[loss_counter]=running_loss
            plot_val_loss_win[loss_counter]=running_loss_win
            loss_counter+=1

            running_loss=0
            running_loss_win=0

# Plot val loss
plt.figure(3)
plt.plot(plot_val_loss,label='conv')
plt.plot(plot_val_loss_win,label='conv_win')
plt.title('Val Losses')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.savefig(os.path.join("/save_dir", 'val_loss_cifar100_all_win_wd_'+str(n_layers)+'_layers_'+str(None)+'.pdf'), bbox_inches='tight')

# Print accuracies
print("Accuracy: ", accuracy)
print("Accuracy_Win: ", accuracy_win)
print("class_counter: ", class_counter)
print("Accuracy_percentage: ", accuracy.sum()/class_counter.sum()*100)
print("Accuracy_win_percentage: ", accuracy_win.sum()/class_counter.sum()*100)

# Save model + losses
torch.save({'state_dict': model.state_dict(), 'state_dict_win': model_win.state_dict(), 'training_loss': plot_loss, 'training_loss_win': plot_loss_win, 'val_loss': plot_val_loss, 'val_loss_win': plot_val_loss_win, 'accuracy': accuracy, 'accuracy_win': accuracy_win, 'class_counter': class_counter}, os.path.join("/save_dir", 'model_cifar100_all_win_wd_'+str(n_layers)+'_layers_'+str(None)+'.pth'))
# Out:
# Batch_size:  64
# Totle number of Epochs: 50
# Epoch:  0
# Batch_Counter:  50
# 2 2 6
# Running loss:  54.56837874650955
# Running loss windowed:  59.78431957960129
# Batch_Counter:  100
# 0 0 0
# Running loss:  37.17857202887535
# Running loss windowed:  38.46079608798027
# Batch_Counter:  150
# 4 4 6
# Running loss:  33.14290091395378
# Running loss windowed:  33.42096582055092
# Batch_Counter:  200
# 7 7 7
# Running loss:  28.999364346265793
# Running loss windowed:  29.156323552131653
# Batch_Counter:  250
# 4 4 4
# Running loss:  27.41356411576271
# Running loss windowed:  27.16928121447563
# Batch_Counter:  300
# 3 1 1
# Running loss:  28.51735669374466
# Running loss windowed:  27.676315993070602
# Batch_Counter:  350
# 4 4 1
# Running loss:  26.57812610268593
# Running loss windowed:  26.2954860329628
# Batch_Counter:  400
# 4 4 4
# Running loss:  23.7229765355587
# Running loss windowed:  23.354265809059143
# Batch_Counter:  450
# 9 9 9
# Running loss:  24.213700026273727
# Running loss windowed:  23.474204301834106
# Batch_Counter:  500
# 2 2 2
# Running loss:  25.673613339662552
# Running loss windowed:  24.35531985759735
# Batch_Counter:  550
# 4 4 4
# Running loss:  23.09616357088089
# Running loss windowed:  22.031064361333847
# Batch_Counter:  600
# 1 1 1
# Running loss:  23.499653160572052
# Running loss windowed:  22.202858924865723
# Batch_Counter:  650
# 8 8 8
# Running loss:  22.355255380272865
# Running loss windowed:  21.71512398123741
# Batch_Counter:  700
# 8 8 8
# Running loss:  20.511818170547485
# Running loss windowed:  19.996343553066254
# Batch_Counter:  750
# 0 0 0
# Running loss:  21.48110221326351
# Running loss windowed:  20.065340623259544
# Batch_Counter:  800
# 3 3 3
# Running loss:  21.01740489900112
# Running loss windowed:  19.914969071745872
# Batch_Counter:  850
# 8 8 8
# Running loss:  21.944286704063416
# Running loss windowed:  20.791868716478348
# Batch_Counter:  900
# 7 7 7
# Running loss:  21.03071504831314
# Running loss windowed:  20.578490018844604
# Epoch:  1
# Batch_Counter:  50
# 6 6 6
# Running loss:  17.557413667440414
# Running loss windowed:  17.12230272591114
# Batch_Counter:  100
# 6 6 6
# Running loss:  20.18143667280674
# Running loss windowed:  19.275630086660385
# Batch_Counter:  150
# 1 1 1
# Running loss:  18.815820187330246
# Running loss windowed:  18.428110137581825
# Batch_Counter:  200
# 5 5 5
# Running loss:  16.71449312567711
# Running loss windowed:  16.451326578855515
# Batch_Counter:  250
# 7 7 5
# Running loss:  18.68449404835701
# Running loss windowed:  18.22914507985115
# Batch_Counter:  300
# 0 0 6
# Running loss:  17.708436518907547
# Running loss windowed:  17.33971731364727
# Batch_Counter:  350
# 8 8 8
# Running loss:  18.510108307003975
# Running loss windowed:  17.544227704405785
# Batch_Counter:  400
# 3 3 3
# Running loss:  18.699655428528786
# Running loss windowed:  17.215558752417564
# Batch_Counter:  450
# 8 8 8
# Running loss:  19.378857985138893
# Running loss windowed:  17.984067142009735
# Batch_Counter:  500
# 0 0 0
# Running loss:  16.23587265610695
# Running loss windowed:  15.731316104531288
# Batch_Counter:  550
# 4 4 4
# Running loss:  17.067871674895287
# Running loss windowed:  16.441722184419632
# Batch_Counter:  600
# 8 8 8
# Running loss:  18.046975076198578
# Running loss windowed:  17.127141535282135
# Batch_Counter:  650
# 6 6 0
# Running loss:  17.26002113521099
# Running loss windowed:  15.957844227552414
# Batch_Counter:  700
# 4 4 4
# Running loss:  18.332694455981255
# Running loss windowed:  17.29944883286953
# Batch_Counter:  750
# 9 9 9
# Running loss:  16.578501343727112
# Running loss windowed:  15.83495943248272
# Batch_Counter:  800
# 9 9 9
# Running loss:  16.84091743826866
# Running loss windowed:  16.213409587740898
# Batch_Counter:  850
# 2 2 2
# Running loss:  17.268977373838425
# Running loss windowed:  16.617245718836784
# Batch_Counter:  900
# 9 9 9
# Running loss:  17.13433986902237
# Running loss windowed:  16.115100905299187
# Epoch:  2
# Batch_Counter:  50
# 2 6 4
# Running loss:  16.551684215664864
# Running loss windowed:  15.686512783169746
# Batch_Counter:  100
# 5 5 5
# Running loss:  16.446123600006104
# Running loss windowed:  16.26728232204914
# Batch_Counter:  150
# 2 2 6
# Running loss:  16.324999928474426
# Running loss windowed:  16.26045534014702
# Batch_Counter:  200
# 2 2 2
# Running loss:  15.754451557993889
# Running loss windowed:  14.791468665003777
# Batch_Counter:  250
# 0 0 0
# Running loss:  15.407009482383728
# Running loss windowed:  14.856732465326786
# Batch_Counter:  300
# 4 4 4
# Running loss:  15.838959217071533
# Running loss windowed:  15.814263969659805
# Batch_Counter:  350
# 6 6 6
# Running loss:  16.999330088496208
# Running loss windowed:  15.650768473744392
# Batch_Counter:  400
# 7 7 7
# Running loss:  15.94931472837925
# Running loss windowed:  15.355930551886559
# Batch_Counter:  450
# 4 4 4
# Running loss:  16.020039781928062
# Running loss windowed:  15.324877768754959
# Batch_Counter:  500
# 7 7 9
# Running loss:  15.814586445689201
# Running loss windowed:  15.478545472025871
# Batch_Counter:  550
# 4 4 4
# Running loss:  15.418716087937355
# Running loss windowed:  15.412681668996811
# Batch_Counter:  600
# 4 6 4
# Running loss:  14.998408146202564
# Running loss windowed:  14.446423381567001
# Batch_Counter:  650
# 9 9 7
# Running loss:  15.671320721507072
# Running loss windowed:  14.43485401570797
# Batch_Counter:  700
# 6 6 6
# Running loss:  15.833726078271866
# Running loss windowed:  15.240231320261955
# Batch_Counter:  750
# 1 1 1
# Running loss:  14.810419417917728
# Running loss windowed:  13.594076879322529
# Batch_Counter:  800
# 5 5 5
# Running loss:  14.71636326611042
# Running loss windowed:  14.418027833104134
# Batch_Counter:  850
# 9 9 9
# Running loss:  14.777854323387146
# Running loss windowed:  14.30831891298294
# Batch_Counter:  900
# 3 3 3
# Running loss:  14.389142975211143
# Running loss windowed:  13.394362673163414
# Epoch:  3
# Batch_Counter:  50
# 2 2 2
# Running loss:  14.20390048623085
# Running loss windowed:  13.935104414820671
# Batch_Counter:  100
# 8 8 8
# Running loss:  14.86563815176487
# Running loss windowed:  14.086815059185028
# Batch_Counter:  150
# 3 3 3
# Running loss:  15.49828489124775
# Running loss windowed:  15.18367874622345
# Batch_Counter:  200
# 0 0 0
# Running loss:  14.93266199529171
# Running loss windowed:  14.493793897330761
# Batch_Counter:  250
# 8 8 8
# Running loss:  14.494735419750214
# Running loss windowed:  13.954119078814983
# Batch_Counter:  300
# 9 9 9
# Running loss:  14.151044487953186
# Running loss windowed:  13.340722903609276
# Batch_Counter:  350
# 4 2 2
# Running loss:  15.438300162553787
# Running loss windowed:  14.482564702630043
# Batch_Counter:  400
# 1 1 1
# Running loss:  13.874004244804382
# Running loss windowed:  13.581218257546425
# Batch_Counter:  450
# 2 2 2
# Running loss:  13.13155272603035
# Running loss windowed:  13.146700099110603
# Batch_Counter:  500
# 7 7 7
# Running loss:  15.709929049015045
# Running loss windowed:  14.462199315428734
# Batch_Counter:  550
# 9 9 9
# Running loss:  15.15981650352478
# Running loss windowed:  14.247423678636551
# Batch_Counter:  600
# 2 6 6
# Running loss:  14.032398894429207
# Running loss windowed:  13.794934593141079
# Batch_Counter:  650
# 6 6 6
# Running loss:  13.763462409377098
# Running loss windowed:  13.28734889626503
# Batch_Counter:  700
# 3 3 4
# Running loss:  13.182082876563072
# Running loss windowed:  13.00339537858963
# Batch_Counter:  750
# 1 1 1
# Running loss:  14.820349246263504
# Running loss windowed:  13.99233902990818
# Batch_Counter:  800
# 9 9 9
# Running loss:  13.623183585703373
# Running loss windowed:  12.91409082710743
# Batch_Counter:  850
# 9 9 9
# Running loss:  14.131242603063583
# Running loss windowed:  13.371679566800594
# Batch_Counter:  900
# 0 0 0
# Running loss:  13.157707557082176
# Running loss windowed:  12.571131587028503
# Epoch:  4
# Batch_Counter:  50
# 4 4 6
# Running loss:  13.305760569870472
# Running loss windowed:  12.428136922419071
# Batch_Counter:  100
# 6 6 6
# Running loss:  13.701179943978786
# Running loss windowed:  12.98853074759245
# Batch_Counter:  150
# 7 7 7
# Running loss:  13.67670876532793
# Running loss windowed:  12.5476493537426
# Batch_Counter:  200
# 5 5 5
# Running loss:  12.305034756660461
# Running loss windowed:  11.920545130968094
# Batch_Counter:  250
# 9 9 9
# Running loss:  14.286636114120483
# Running loss windowed:  13.37118062376976
# Batch_Counter:  300
# 0 0 0
# Running loss:  13.590145446360111
# Running loss windowed:  12.785162955522537
# Batch_Counter:  350
# 7 7 7
# Running loss:  13.314047366380692
# Running loss windowed:  13.114531368017197
# Batch_Counter:  400
# 2 2 2
# Running loss:  13.792643323540688
# Running loss windowed:  13.291093781590462
# Batch_Counter:  450
# 3 3 3
# Running loss:  13.935524746775627
# Running loss windowed:  13.442385658621788
# Batch_Counter:  500
# 2 2 6
# Running loss:  13.353276133537292
# Running loss windowed:  12.75543025135994
# Batch_Counter:  550
# 3 3 3
# Running loss:  13.854677468538284
# Running loss windowed:  13.401756130158901
# Batch_Counter:  600
# 2 2 2
# Running loss:  13.260220877826214
# Running loss windowed:  12.577579200267792
# Batch_Counter:  650
# 2 2 2
# Running loss:  14.406044915318489
# Running loss windowed:  13.661611199378967
# Batch_Counter:  700
# 6 6 6
# Running loss:  12.48636069893837
# Running loss windowed:  12.028816238045692
# Batch_Counter:  750
# 1 1 1
# Running loss:  14.59664997458458
# Running loss windowed:  13.631343677639961
# Batch_Counter:  800
# 9 9 9
# Running loss:  14.067732252180576
# Running loss windowed:  13.494585357606411
# Batch_Counter:  850
# 4 4 4
# Running loss:  13.705537647008896
# Running loss windowed:  13.101277261972427
# Batch_Counter:  900
# 1 1 1
# Running loss:  13.385531336069107
# Running loss windowed:  13.647171013057232
# Epoch:  5
# Batch_Counter:  50
# 0 0 0
# Running loss:  13.261061981320381
# Running loss windowed:  13.246005229651928
# Batch_Counter:  100
# 9 9 9
# Running loss:  13.421080827713013
# Running loss windowed:  12.823446944355965
# Batch_Counter:  150
# 1 1 1
# Running loss:  13.440672159194946
# Running loss windowed:  12.410213202238083
# Batch_Counter:  200
# 1 1 1
# Running loss:  14.065652593970299
# Running loss windowed:  13.06122037768364
# Batch_Counter:  250
# 9 9 9
# Running loss:  12.969329409301281
# Running loss windowed:  12.529050417244434
# Batch_Counter:  300
# 8 8 8
# Running loss:  12.427964575588703
# Running loss windowed:  12.226874865591526
# Batch_Counter:  350
# 1 1 1
# Running loss:  11.765987813472748
# Running loss windowed:  11.406319931149483
# Batch_Counter:  400
# 8 8 8
# Running loss:  12.06327361613512
# Running loss windowed:  11.484755054116249
# Batch_Counter:  450
# 5 5 5
# Running loss:  12.494170784950256
# Running loss windowed:  11.798982419073582
# Batch_Counter:  500
# 0 0 0
# Running loss:  12.137397482991219
# Running loss windowed:  11.186984576284885
# Batch_Counter:  550
# 0 0 6
# Running loss:  12.718649752438068
# Running loss windowed:  11.844884619116783
# Batch_Counter:  600
# 8 8 8
# Running loss:  12.53994558006525
# Running loss windowed:  11.596436895430088
# Batch_Counter:  650
# 1 1 1
# Running loss:  13.188559859991074
# Running loss windowed:  12.971896223723888
# Batch_Counter:  700
# 2 2 2
# Running loss:  13.882123157382011
# Running loss windowed:  13.904969453811646
# Batch_Counter:  750
# 1 1 1
# Running loss:  13.144477292895317
# Running loss windowed:  12.822544611990452
# Batch_Counter:  800
# 2 2 2
# Running loss:  12.022805534303188
# Running loss windowed:  11.752006120979786
# Batch_Counter:  850
# 1 1 1
# Running loss:  13.701080746948719
# Running loss windowed:  12.78676899522543
# Batch_Counter:  900
# 5 5 5
# Running loss:  13.08566129207611
# Running loss windowed:  12.265116222202778
# Epoch:  6
# Batch_Counter:  50
# 4 4 4
# Running loss:  12.31916680186987
# Running loss windowed:  11.777425348758698
# Batch_Counter:  100
# 9 9 9
# Running loss:  12.913289539515972
# Running loss windowed:  12.477961085736752
# Batch_Counter:  150
# 3 3 3
# Running loss:  12.013377636671066
# Running loss windowed:  11.295019991695881
# Batch_Counter:  200
# 8 8 8
# Running loss:  12.634909443557262
# Running loss windowed:  12.315869741141796
# Batch_Counter:  250
# 6 6 6
# Running loss:  11.95634876191616
# Running loss windowed:  11.61004188656807
# Batch_Counter:  300
# 7 7 7
# Running loss:  12.816524244844913
# Running loss windowed:  12.16884832829237
# Batch_Counter:  350
# 9 9 9
# Running loss:  12.995689675211906
# Running loss windowed:  12.37206257879734
# Batch_Counter:  400
# 8 8 8
# Running loss:  12.567634534090757
# Running loss windowed:  11.89662167429924
# Batch_Counter:  450
# 9 9 9
# Running loss:  11.497110828757286
# Running loss windowed:  10.933051832020283
# Batch_Counter:  500
# 1 1 1
# Running loss:  13.116292923688889
# Running loss windowed:  12.497153356671333
# Batch_Counter:  550
# 2 2 6
# Running loss:  12.729052297770977
# Running loss windowed:  12.16768354177475
# Batch_Counter:  600
# 7 7 7
# Running loss:  12.2160350009799
# Running loss windowed:  11.7355812266469
# Batch_Counter:  650
# 8 8 8
# Running loss:  12.899285420775414
# Running loss windowed:  12.739328138530254
# Batch_Counter:  700
# 9 9 9
# Running loss:  12.671302758157253
# Running loss windowed:  12.546810932457447
# Batch_Counter:  750
# 8 8 8
# Running loss:  12.711782485246658
# Running loss windowed:  11.576853409409523
# Batch_Counter:  800
# 0 6 0
# Running loss:  11.50325359404087
# Running loss windowed:  11.609555162489414
# Batch_Counter:  850
# 3 3 3
# Running loss:  11.997003600001335
# Running loss windowed:  11.512079402804375
# Batch_Counter:  900
# 6 6 6
# Running loss:  12.617712244391441
# Running loss windowed:  12.214930087327957
# Epoch:  7
# Batch_Counter:  50
# 8 8 8
# Running loss:  13.013766266405582
# Running loss windowed:  12.159851595759392
# Batch_Counter:  100
# 9 9 9
# Running loss:  12.401839189231396
# Running loss windowed:  11.89720343053341
# Batch_Counter:  150
# 8 8 8
# Running loss:  12.468321688473225
# Running loss windowed:  11.898430302739143
# Batch_Counter:  200
# 9 9 9
# Running loss:  12.299238666892052
# Running loss windowed:  12.715885892510414
# Batch_Counter:  250
# 6 6 6
# Running loss:  11.42581383138895
# Running loss windowed:  10.835962481796741
# Batch_Counter:  300
# 2 2 0
# Running loss:  12.200071297585964
# Running loss windowed:  11.74511456489563
# Batch_Counter:  350
# 3 3 3
# Running loss:  11.84808748960495
# Running loss windowed:  11.318617232143879
# Batch_Counter:  400
# 9 9 9
# Running loss:  13.303546324372292
# Running loss windowed:  12.834955140948296
# Batch_Counter:  450
# 4 4 4
# Running loss:  11.875056073069572
# Running loss windowed:  11.67571921646595
# Batch_Counter:  500
# 5 5 5
# Running loss:  11.521199867129326
# Running loss windowed:  10.619781635701656
# Batch_Counter:  550
# 5 5 5
# Running loss:  11.845506764948368
# Running loss windowed:  11.544592656195164
# Batch_Counter:  600
# 5 5 5
# Running loss:  10.962562471628189
# Running loss windowed:  10.225941434502602
# Batch_Counter:  650
# 0 0 0
# Running loss:  12.020500503480434
# Running loss windowed:  11.536414064466953
# Batch_Counter:  700
# 1 1 1
# Running loss:  10.967384450137615
# Running loss windowed:  9.949807651340961
# Batch_Counter:  750
# 1 1 1
# Running loss:  11.540487200021744
# Running loss windowed:  10.810396686196327
# Batch_Counter:  800
# 7 7 7
# Running loss:  12.410202100872993
# Running loss windowed:  12.217444740235806
# Batch_Counter:  850
# 5 5 5
# Running loss:  12.934565342962742
# Running loss windowed:  12.097465224564075
# Batch_Counter:  900
# 3 3 3
# Running loss:  12.740256130695343
# Running loss windowed:  11.824525512754917
# Epoch:  8
# Batch_Counter:  50
# 1 1 1
# Running loss:  12.18370272219181
# Running loss windowed:  12.17096608132124
# Batch_Counter:  100
# 9 9 9
# Running loss:  11.21090517193079
# Running loss windowed:  10.797525562345982
# Batch_Counter:  150
# 6 4 6
# Running loss:  11.222346477210522
# Running loss windowed:  10.94832856208086
# Batch_Counter:  200
# 2 2 4
# Running loss:  10.816338114440441
# Running loss windowed:  9.9361637160182
# Batch_Counter:  250
# 7 7 7
# Running loss:  11.736371785402298
# Running loss windowed:  10.860257886350155
# Batch_Counter:  300
# 1 1 1
# Running loss:  12.540216833353043
# Running loss windowed:  11.975708179175854
# Batch_Counter:  350
# 4 4 4
# Running loss:  12.243037909269333
# Running loss windowed:  11.477136306464672
# Batch_Counter:  400
# 6 6 0
# Running loss:  12.373757064342499
# Running loss windowed:  11.740485705435276
# Batch_Counter:  450
# 0 0 0
# Running loss:  11.901852689683437
# Running loss windowed:  11.209763191640377
# Batch_Counter:  500
# 2 2 2
# Running loss:  11.16472465544939
# Running loss windowed:  10.679224230349064
# Batch_Counter:  550
# 3 3 3
# Running loss:  11.334789916872978
# Running loss windowed:  10.782184764742851
# Batch_Counter:  600
# 5 5 5
# Running loss:  11.146869793534279
# Running loss windowed:  10.515928134322166
# Batch_Counter:  650
# 7 7 7
# Running loss:  11.724072895944118
# Running loss windowed:  11.140947319567204
# Batch_Counter:  700
# 4 4 4
# Running loss:  11.461410492658615
# Running loss windowed:  10.920251548290253
# Batch_Counter:  750
# 7 7 7
# Running loss:  11.599136672914028
# Running loss windowed:  11.399076327681541
# Batch_Counter:  800
# 0 0 0
# Running loss:  12.490652650594711
# Running loss windowed:  11.685614787042141
# Batch_Counter:  850
# 9 9 9
# Running loss:  11.081488817930222
# Running loss windowed:  11.287011288106441
# Batch_Counter:  900
# 4 4 4
# Running loss:  12.207599900662899
# Running loss windowed:  11.772224582731724
# Epoch:  9
# Batch_Counter:  50
# 1 3 1
# Running loss:  12.438971363008022
# Running loss windowed:  11.74915873259306
# Batch_Counter:  100
# 0 0 0
# Running loss:  11.005862355232239
# Running loss windowed:  10.496324706822634
# Batch_Counter:  150
# 1 1 1
# Running loss:  11.174805514514446
# Running loss windowed:  11.00764685869217
# Batch_Counter:  200
# 7 7 7
# Running loss:  11.86477355659008
# Running loss windowed:  11.08606719225645
# Batch_Counter:  250
# 2 2 2
# Running loss:  11.048364609479904
# Running loss windowed:  10.879168227314949
# Batch_Counter:  300
# 1 1 1
# Running loss:  10.37152150273323
# Running loss windowed:  10.140388831496239
# Batch_Counter:  350
# 6 6 6
# Running loss:  12.23791828751564
# Running loss windowed:  11.906260497868061
# Batch_Counter:  400
# 7 7 7
# Running loss:  11.8968965113163
# Running loss windowed:  12.013803347945213
# Batch_Counter:  450
# 7 7 7
# Running loss:  12.157747864723206
# Running loss windowed:  11.082225687801838
# Batch_Counter:  500
# 3 3 3
# Running loss:  10.708765618503094
# Running loss windowed:  9.93324438482523
# Batch_Counter:  550
# 5 5 5
# Running loss:  11.559915110468864
# Running loss windowed:  10.774326466023922
# Batch_Counter:  600
# 6 6 6
# Running loss:  10.952774979174137
# Running loss windowed:  10.158436693251133
# Batch_Counter:  650
# 1 1 1
# Running loss:  11.3827488347888
# Running loss windowed:  10.684623382985592
# Batch_Counter:  700
# 1 1 1
# Running loss:  11.279850661754608
# Running loss windowed:  10.721895795315504
# Batch_Counter:  750
# 9 9 9
# Running loss:  10.216609179973602
# Running loss windowed:  9.976348049938679
# Batch_Counter:  800
# 3 3 3
# Running loss:  11.114172980189323
# Running loss windowed:  11.206478737294674
# Batch_Counter:  850
# 1 1 1
# Running loss:  11.097919948399067
# Running loss windowed:  10.470947161316872
# Batch_Counter:  900
# 6 6 6
# Running loss:  11.123522758483887
# Running loss windowed:  10.386165872216225
# Epoch:  10
# Batch_Counter:  50
# 6 6 6
# Running loss:  10.389291889965534
# Running loss windowed:  9.990157894790173
# Batch_Counter:  100
# 8 8 8
# Running loss:  11.583271197974682
# Running loss windowed:  11.103002153337002
# Batch_Counter:  150
# 0 0 0
# Running loss:  11.540218234062195
# Running loss windowed:  10.695830814540386
# Batch_Counter:  200
# 2 6 6
# Running loss:  10.599432595074177
# Running loss windowed:  9.941075921058655
# Batch_Counter:  250
# 0 0 0
# Running loss:  11.338504832237959
# Running loss windowed:  10.94238318502903
# Batch_Counter:  300
# 6 2 2
# Running loss:  11.321876846253872
# Running loss windowed:  10.993509225547314
# Batch_Counter:  350
# 0 0 0
# Running loss:  10.467566631734371
# Running loss windowed:  10.02414282783866
# Batch_Counter:  400
# 7 7 7
# Running loss:  10.887760937213898
# Running loss windowed:  10.230454213917255
# Batch_Counter:  450
# 4 4 4
# Running loss:  10.472194403409958
# Running loss windowed:  9.886503778398037
# Batch_Counter:  500
# 3 3 6
# Running loss:  11.685645066201687
# Running loss windowed:  11.08800832927227
# Batch_Counter:  550
# 6 6 6
# Running loss:  10.183003291487694
# Running loss windowed:  10.19605265557766
# Batch_Counter:  600
# 7 7 7
# Running loss:  11.319123975932598
# Running loss windowed:  10.624858193099499
# Batch_Counter:  650
# 5 5 5
# Running loss:  11.333843499422073
# Running loss windowed:  11.036684542894363
# Batch_Counter:  700
# 4 4 4
# Running loss:  10.407004944980145
# Running loss windowed:  10.288216553628445
# Batch_Counter:  750
# 3 3 3
# Running loss:  11.50865063071251
# Running loss windowed:  11.463437855243683
# Batch_Counter:  800
# 0 0 0
# Running loss:  11.786915741860867
# Running loss windowed:  11.108557850122452
# Batch_Counter:  850
# 3 3 3
# Running loss:  11.019659616053104
# Running loss windowed:  10.263166345655918
# Batch_Counter:  900
# 4 4 4
# Running loss:  11.137506186962128
# Running loss windowed:  11.003259174525738
# Epoch:  11
# Batch_Counter:  50
# 9 9 9
# Running loss:  10.645172700285912
# Running loss windowed:  10.309721015393734
# Batch_Counter:  100
# 0 0 0
# Running loss:  10.284942589700222
# Running loss windowed:  10.34200581163168
# Batch_Counter:  150
# 1 1 1
# Running loss:  10.002084858715534
# Running loss windowed:  9.378439277410507
# Batch_Counter:  200
# 7 7 7
# Running loss:  10.02236982434988
# Running loss windowed:  9.829071920365095
# Batch_Counter:  250
# 7 7 9
# Running loss:  10.116435408592224
# Running loss windowed:  9.979656510055065
# Batch_Counter:  300
# 7 7 7
# Running loss:  10.854233734309673
# Running loss windowed:  10.532786794006824
# Batch_Counter:  350
# 3 6 3
# Running loss:  10.619458116590977
# Running loss windowed:  10.050819471478462
# Batch_Counter:  400
# 3 3 4
# Running loss:  10.319671340286732
# Running loss windowed:  10.298518650233746
# Batch_Counter:  450
# 7 7 7
# Running loss:  11.726169422268867
# Running loss windowed:  10.963951747864485
# Batch_Counter:  500
# 0 0 0
# Running loss:  10.721600525081158
# Running loss windowed:  10.114949516952038
# Batch_Counter:  550
# 8 8 8
# Running loss:  12.327197320759296
# Running loss windowed:  11.201666235923767
# Batch_Counter:  600
# 6 6 6
# Running loss:  10.823192223906517
# Running loss windowed:  10.484351716935635
# Batch_Counter:  650
# 4 4 4
# Running loss:  11.489938594400883
# Running loss windowed:  10.488975264132023
# Batch_Counter:  700
# 1 1 1
# Running loss:  11.505477473139763
# Running loss windowed:  10.784851275384426
# Batch_Counter:  750
# 2 2 2
# Running loss:  10.23850979655981
# Running loss windowed:  10.23166486620903
# Batch_Counter:  800
# 6 6 6
# Running loss:  11.624147593975067
# Running loss windowed:  10.989169850945473
# Batch_Counter:  850
# 6 6 6
# Running loss:  10.689342722296715
# Running loss windowed:  10.1794951595366
# Batch_Counter:  900
# 7 7 7
# Running loss:  11.60830394178629
# Running loss windowed:  11.430765472352505
# Epoch:  12
# Batch_Counter:  50
# 7 7 7
# Running loss:  10.261110212653875
# Running loss windowed:  9.94210371375084
# Batch_Counter:  100
# 0 0 6
# Running loss:  9.948088392615318
# Running loss windowed:  9.851893588900566
# Batch_Counter:  150
# 5 5 5
# Running loss:  10.384798645973206
# Running loss windowed:  10.001873150467873
# Batch_Counter:  200
# 7 7 7
# Running loss:  10.755469888448715
# Running loss windowed:  9.917611949145794
# Batch_Counter:  250
# 9 9 7
# Running loss:  11.001367174088955
# Running loss windowed:  10.5137302801013
# Batch_Counter:  300
# 2 2 2
# Running loss:  11.051224820315838
# Running loss windowed:  10.484237618744373
# Batch_Counter:  350
# 7 7 7
# Running loss:  10.75886583328247
# Running loss windowed:  10.682443037629128
# Batch_Counter:  400
# 4 2 2
# Running loss:  9.952788308262825
# Running loss windowed:  9.070637822151184
# Batch_Counter:  450
# 0 0 0
# Running loss:  10.568643666803837
# Running loss windowed:  9.826444625854492
# Batch_Counter:  500
# 1 1 1
# Running loss:  11.558820843696594
# Running loss windowed:  10.65156802535057
# Batch_Counter:  550
# 4 4 4
# Running loss:  10.236743114888668
# Running loss windowed:  9.903610523790121
# Batch_Counter:  600
# 0 0 0
# Running loss:  11.277802541851997
# Running loss windowed:  10.847557757049799
# Batch_Counter:  650
# 3 3 3
# Running loss:  10.190970852971077
# Running loss windowed:  9.711505383253098
# Batch_Counter:  700
# 0 0 6
# Running loss:  10.440451174974442
# Running loss windowed:  10.162120699882507
# Batch_Counter:  750
# 6 6 6
# Running loss:  10.072252705693245
# Running loss windowed:  9.707291223108768
# Batch_Counter:  800
# 0 0 3
# Running loss:  10.120332591235638
# Running loss windowed:  9.399729445576668
# Batch_Counter:  850
# 2 2 2
# Running loss:  11.665814377367496
# Running loss windowed:  10.728932842612267
# Batch_Counter:  900
# 8 8 8
# Running loss:  10.1807207390666
# Running loss windowed:  9.968292027711868
# Epoch:  13
# Batch_Counter:  50
# 8 8 8
# Running loss:  10.438942342996597
# Running loss windowed:  10.265929948538542
# Batch_Counter:  100
# 8 8 8
# Running loss:  9.517217725515366
# Running loss windowed:  9.232934422791004
# Batch_Counter:  150
# 0 0 0
# Running loss:  8.992447033524513
# Running loss windowed:  8.91119259595871
# Batch_Counter:  200
# 6 6 6
# Running loss:  9.9721050709486
# Running loss windowed:  9.715540520846844
# Batch_Counter:  250
# 9 9 9
# Running loss:  11.063960820436478
# Running loss windowed:  10.791569381952286
# Batch_Counter:  300
# 7 7 7
# Running loss:  10.675320461392403
# Running loss windowed:  10.084540367126465
# Batch_Counter:  350
# 9 9 9
# Running loss:  9.794906899333
# Running loss windowed:  9.357555530965328
# Batch_Counter:  400
# 8 8 8
# Running loss:  11.364512890577316
# Running loss windowed:  11.12244437634945
# Batch_Counter:  450
# 4 4 4
# Running loss:  10.633101250976324
# Running loss windowed:  9.753230214118958
# Batch_Counter:  500
# 1 1 1
# Running loss:  10.56343400478363
# Running loss windowed:  9.811715129762888
# Batch_Counter:  550
# 5 5 5
# Running loss:  10.823986262083054
# Running loss windowed:  10.372311398386955
# Batch_Counter:  600
# 7 7 7
# Running loss:  10.442430935800076
# Running loss windowed:  10.012447513639927
# Batch_Counter:  650
# 4 4 4
# Running loss:  10.600436829030514
# Running loss windowed:  10.513087414205074
# Batch_Counter:  700
# 5 5 5
# Running loss:  10.182714596390724
# Running loss windowed:  9.423340573906898
# Batch_Counter:  750
# 4 4 4
# Running loss:  10.485866241157055
# Running loss windowed:  9.665722399950027
# Batch_Counter:  800
# 9 9 9
# Running loss:  11.280682124197483
# Running loss windowed:  11.057414248585701
# Batch_Counter:  850
# 9 9 9
# Running loss:  9.947278171777725
# Running loss windowed:  9.65111069381237
# Batch_Counter:  900
# 1 1 1
# Running loss:  11.328655399382114
# Running loss windowed:  11.113570310175419
# Epoch:  14
# Batch_Counter:  50
# 8 8 8
# Running loss:  9.505489885807037
# Running loss windowed:  9.327312417328358
# Batch_Counter:  100
# 6 6 6
# Running loss:  9.7243940718472
# Running loss windowed:  9.053979821503162
# Batch_Counter:  150
# 0 0 0
# Running loss:  10.048572819679976
# Running loss windowed:  9.515023566782475
# Batch_Counter:  200
# 2 2 2
# Running loss:  9.973770782351494
# Running loss windowed:  9.566513925790787
# Batch_Counter:  250
# 5 5 5
# Running loss:  10.660040870308876
# Running loss windowed:  10.357692189514637
# Batch_Counter:  300
# 3 3 3
# Running loss:  10.593996599316597
# Running loss windowed:  10.17209593206644
# Batch_Counter:  350
# 8 8 8
# Running loss:  9.69959395006299
# Running loss windowed:  9.261812649667263
# Batch_Counter:  400
# 0 0 0
# Running loss:  10.737262085080147
# Running loss windowed:  11.021985083818436
# Batch_Counter:  450
# 9 9 9
# Running loss:  11.610718123614788
# Running loss windowed:  11.352640580385923
# Batch_Counter:  500
# 7 7 7
# Running loss:  10.434473790228367
# Running loss windowed:  10.18570363521576
# Batch_Counter:  550
# 4 4 4
# Running loss:  9.61516460776329
# Running loss windowed:  8.769374653697014
# Batch_Counter:  600
# 9 9 9
# Running loss:  9.964427899569273
# Running loss windowed:  9.445995695888996
# Batch_Counter:  650
# 0 0 0
# Running loss:  9.61371249333024
# Running loss windowed:  9.526294365525246
# Batch_Counter:  700
# 2 2 2
# Running loss:  10.482607044279575
# Running loss windowed:  9.636645369231701
# Batch_Counter:  750
# 7 7 7
# Running loss:  10.892467007040977
# Running loss windowed:  10.596691481769085
# Batch_Counter:  800
# 0 6 6
# Running loss:  10.30259271711111
# Running loss windowed:  9.79958064109087
# Batch_Counter:  850
# 0 0 0
# Running loss:  10.958494856953621
# Running loss windowed:  10.145710319280624
# Batch_Counter:  900
# 0 0 0
# Running loss:  9.237999320030212
# Running loss windowed:  9.390244714915752
# Epoch:  15
# Batch_Counter:  50
# 1 1 1
# Running loss:  10.348806396126747
# Running loss windowed:  10.253435239195824
# Batch_Counter:  100
# 0 0 0
# Running loss:  9.783338576555252
# Running loss windowed:  10.03849758952856
# Batch_Counter:  150
# 8 8 8
# Running loss:  8.666364781558514
# Running loss windowed:  8.34885784983635
# Batch_Counter:  200
# 8 8 8
# Running loss:  10.493164278566837
# Running loss windowed:  9.978850491344929
# Batch_Counter:  250
# 6 6 2
# Running loss:  9.634836994111538
# Running loss windowed:  9.144117649644613
# Batch_Counter:  300
# 6 6 6
# Running loss:  10.059482760727406
# Running loss windowed:  9.820277377963066
# Batch_Counter:  350
# 2 2 2
# Running loss:  10.356033682823181
# Running loss windowed:  9.839330777525902
# Batch_Counter:  400
# 8 8 8
# Running loss:  10.07710363715887
# Running loss windowed:  9.644017860293388
# Batch_Counter:  450
# 2 2 2
# Running loss:  10.648261070251465
# Running loss windowed:  10.231717988848686
# Batch_Counter:  500
# 5 5 5
# Running loss:  10.218833595514297
# Running loss windowed:  9.350912474095821
# Batch_Counter:  550
# 9 9 9
# Running loss:  10.216603189706802
# Running loss windowed:  9.748488754034042
# Batch_Counter:  600
# 2 2 2
# Running loss:  9.709542393684387
# Running loss windowed:  9.60935128480196
# Batch_Counter:  650
# 4 4 4
# Running loss:  10.533925626426935
# Running loss windowed:  10.324245929718018
# Batch_Counter:  700
# 2 2 2
# Running loss:  10.126060143113136
# Running loss windowed:  9.836738668382168
# Batch_Counter:  750
# 1 1 1
# Running loss:  9.899338595569134
# Running loss windowed:  9.243776101619005
# Batch_Counter:  800
# 0 0 0
# Running loss:  10.440175458788872
# Running loss windowed:  10.030805330723524
# Batch_Counter:  850
# 3 3 3
# Running loss:  10.445846244692802
# Running loss windowed:  9.883649230003357
# Batch_Counter:  900
# 0 0 0
# Running loss:  10.135402493178844
# Running loss windowed:  9.259825620800257
# Epoch:  16
# Batch_Counter:  50
# 3 3 3
# Running loss:  9.277641974389553
# Running loss windowed:  9.48758089542389
# Batch_Counter:  100
# 6 6 6
# Running loss:  8.660175368189812
# Running loss windowed:  8.983098160475492
# Batch_Counter:  150
# 7 7 7
# Running loss:  9.518162328749895
# Running loss windowed:  9.207430716603994
# Batch_Counter:  200
# 0 0 0
# Running loss:  8.518225014209747
# Running loss windowed:  8.379466846585274
# Batch_Counter:  250
# 7 7 7
# Running loss:  9.75875036418438
# Running loss windowed:  9.877341836690903
# Batch_Counter:  300
# 9 9 9
# Running loss:  9.23842579498887
# Running loss windowed:  9.376218475401402
# Batch_Counter:  350
# 8 8 8
# Running loss:  9.5819506123662
# Running loss windowed:  9.34457579255104
# Batch_Counter:  400
# 7 7 7
# Running loss:  11.048266001045704
# Running loss windowed:  10.615620747208595
# Batch_Counter:  450
# 5 5 5
# Running loss:  9.157832495868206
# Running loss windowed:  8.919381484389305
# Batch_Counter:  500
# 7 7 7
# Running loss:  9.576952837407589
# Running loss windowed:  9.446623794734478
# Batch_Counter:  550
# 4 4 4
# Running loss:  10.468260683119297
# Running loss windowed:  9.982442162930965
# Batch_Counter:  600
# 1 1 1
# Running loss:  9.78107450157404
# Running loss windowed:  9.374259822070599
# Batch_Counter:  650
# 4 2 2
# Running loss:  9.207194991409779
# Running loss windowed:  9.397308576852083
# Batch_Counter:  700
# 1 1 1
# Running loss:  10.20207966119051
# Running loss windowed:  9.593200251460075
# Batch_Counter:  750
# 6 6 4
# Running loss:  10.63526525348425
# Running loss windowed:  9.54341946542263
# Batch_Counter:  800
# 3 3 3
# Running loss:  9.94558671116829
# Running loss windowed:  9.286709871143103
# Batch_Counter:  850
# 7 7 7
# Running loss:  9.993744067847729
# Running loss windowed:  9.376195259392262
# Batch_Counter:  900
# 5 5 5
# Running loss:  10.067710287868977
# Running loss windowed:  9.860383421182632
# Epoch:  17
# Batch_Counter:  50
# 4 4 4
# Running loss:  9.243606306612492
# Running loss windowed:  8.90673340857029
# Batch_Counter:  100
# 0 0 0
# Running loss:  9.009024426341057
# Running loss windowed:  8.636233858764172
# Batch_Counter:  150
# 0 0 0
# Running loss:  9.866473406553268
# Running loss windowed:  9.663073778152466
# Batch_Counter:  200
# 1 1 1
# Running loss:  9.282484453171492
# Running loss windowed:  9.24872636422515
# Batch_Counter:  250
# 2 0 2
# Running loss:  8.737154372036457
# Running loss windowed:  8.673665575683117
# Batch_Counter:  300
# 7 7 7
# Running loss:  10.656147412955761
# Running loss windowed:  9.895636789500713
# Batch_Counter:  350
# 9 9 9
# Running loss:  10.569198124110699
# Running loss windowed:  10.106173351407051
# Batch_Counter:  400
# 4 4 4
# Running loss:  9.45749456435442
# Running loss windowed:  9.304170936346054
# Batch_Counter:  450
# 7 7 7
# Running loss:  9.351216245442629
# Running loss windowed:  8.745271351188421
# Batch_Counter:  500
# 2 2 2
# Running loss:  9.723582454025745
# Running loss windowed:  9.808661058545113
# Batch_Counter:  550
# 5 5 5
# Running loss:  10.491671785712242
# Running loss windowed:  10.341747999191284
# Batch_Counter:  600
# 4 4 2
# Running loss:  9.666681356728077
# Running loss windowed:  9.557816058397293
# Batch_Counter:  650
# 2 2 2
# Running loss:  9.36626921966672
# Running loss windowed:  8.661675304174423
# Batch_Counter:  700
# 9 9 9
# Running loss:  10.511772707104683
# Running loss windowed:  9.961468890309334
# Batch_Counter:  750
# 2 6 6
# Running loss:  9.532937876880169
# Running loss windowed:  8.98824892193079
# Batch_Counter:  800
# 4 4 4
# Running loss:  9.943865105509758
# Running loss windowed:  9.856267556548119
# Batch_Counter:  850
# 2 2 2
# Running loss:  9.512733109295368
# Running loss windowed:  9.316177003085613
# Batch_Counter:  900
# 8 8 8
# Running loss:  10.16350731253624
# Running loss windowed:  9.452904310077429
# Epoch:  18
# Batch_Counter:  50
# 8 8 8
# Running loss:  9.689954459667206
# Running loss windowed:  8.931072253733873
# Batch_Counter:  100
# 7 7 7
# Running loss:  9.346556782722473
# Running loss windowed:  9.656597197055817
# Batch_Counter:  150
# 4 3 3
# Running loss:  9.18636154383421
# Running loss windowed:  9.241253480315208
# Batch_Counter:  200
# 2 2 2
# Running loss:  8.90990599244833
# Running loss windowed:  9.343246627599001
# Batch_Counter:  250
# 2 2 2
# Running loss:  9.27669445052743
# Running loss windowed:  8.912535108625889
# Batch_Counter:  300
# 1 1 1
# Running loss:  8.473942466080189
# Running loss windowed:  8.2814229875803
# Batch_Counter:  350
# 7 7 7
# Running loss:  9.80265636369586
# Running loss windowed:  9.634132523089647
# Batch_Counter:  400
# 5 5 5
# Running loss:  10.868765972554684
# Running loss windowed:  10.263035356998444
# Batch_Counter:  450
# 9 9 9
# Running loss:  8.8781803175807
# Running loss windowed:  8.781180463731289
# Batch_Counter:  500
# 5 5 5
# Running loss:  9.923236906528473
# Running loss windowed:  9.577681548893452
# Batch_Counter:  550
# 4 4 4
# Running loss:  8.673067562282085
# Running loss windowed:  8.276028405874968
# Batch_Counter:  600
# 8 8 8
# Running loss:  9.894768983125687
# Running loss windowed:  9.891135580837727
# Batch_Counter:  650
# 1 1 1
# Running loss:  9.479226633906364
# Running loss windowed:  9.278547704219818
# Batch_Counter:  700
# 4 4 4
# Running loss:  9.788164012134075
# Running loss windowed:  9.68337608128786
# Batch_Counter:  750
# 2 2 2
# Running loss:  8.97488097846508
# Running loss windowed:  8.539056330919266
# Batch_Counter:  800
# 4 4 4
# Running loss:  9.145249478518963
# Running loss windowed:  8.593141913414001
# Batch_Counter:  850
# 4 4 4
# Running loss:  9.632924754172564
# Running loss windowed:  9.426228992640972
# Batch_Counter:  900
# 9 9 9
# Running loss:  9.170215837657452
# Running loss windowed:  8.395297721028328
# Epoch:  19
# Batch_Counter:  50
# 8 8 8
# Running loss:  9.299768891185522
# Running loss windowed:  8.955872438848019
# Batch_Counter:  100
# 6 6 6
# Running loss:  9.201799340546131
# Running loss windowed:  8.715548440814018
# Batch_Counter:  150
# 2 2 2
# Running loss:  10.005563244223595
# Running loss windowed:  9.366334915161133
# Batch_Counter:  200
# 6 0 0
# Running loss:  9.660161167383194
# Running loss windowed:  8.784950494766235
# Batch_Counter:  250
# 0 0 0
# Running loss:  8.623313270509243
# Running loss windowed:  8.388783007860184
# Batch_Counter:  300
# 9 9 9
# Running loss:  9.501542620360851
# Running loss windowed:  8.534205056726933
# Batch_Counter:  350
# 5 5 5
# Running loss:  8.878213912248611
# Running loss windowed:  8.815008819103241
# Batch_Counter:  400
# 4 4 4
# Running loss:  9.360628850758076
# Running loss windowed:  9.159586541354656
# Batch_Counter:  450
# 0 0 0
# Running loss:  10.083396948873997
# Running loss windowed:  9.592440124601126
# Batch_Counter:  500
# 5 5 5
# Running loss:  8.86869552358985
# Running loss windowed:  8.997234780341387
# Batch_Counter:  550
# 3 3 3
# Running loss:  9.670095600187778
# Running loss windowed:  9.48429074510932
# Batch_Counter:  600
# 7 7 7
# Running loss:  8.981472365558147
# Running loss windowed:  8.895354427397251
# Batch_Counter:  650
# 0 0 0
# Running loss:  8.920815512537956
# Running loss windowed:  8.565655685961246
# Batch_Counter:  700
# 8 8 8
# Running loss:  9.043665293604136
# Running loss windowed:  8.473620343953371
# Batch_Counter:  750
# 0 0 0
# Running loss:  9.06616698205471
# Running loss windowed:  9.492946460843086
# Batch_Counter:  800
# 7 7 7
# Running loss:  9.984632454812527
# Running loss windowed:  9.646752931177616
# Batch_Counter:  850
# 7 7 7
# Running loss:  9.534246250987053
# Running loss windowed:  9.422277737408876
# Batch_Counter:  900
# 5 5 5
# Running loss:  8.797455750405788
# Running loss windowed:  8.448303952813148
# Epoch:  20
# Batch_Counter:  50
# 2 2 2
# Running loss:  8.651010178029537
# Running loss windowed:  8.172002583742142
# Batch_Counter:  100
# 1 1 1
# Running loss:  8.58883810788393
# Running loss windowed:  8.44469777494669
# Batch_Counter:  150
# 4 4 4
# Running loss:  10.291986115276814
# Running loss windowed:  9.928801365196705
# Batch_Counter:  200
# 9 9 9
# Running loss:  9.53320287168026
# Running loss windowed:  8.941286824643612
# Batch_Counter:  250
# 1 1 1
# Running loss:  9.739123489707708
# Running loss windowed:  9.318647842854261
# Batch_Counter:  300
# 3 3 3
# Running loss:  9.05173558741808
# Running loss windowed:  9.433237053453922
# Batch_Counter:  350
# 1 1 1
# Running loss:  9.459199577569962
# Running loss windowed:  9.73763956129551
# Batch_Counter:  400
# 2 2 2
# Running loss:  8.50718728452921
# Running loss windowed:  8.986675128340721
# Batch_Counter:  450
# 2 2 2
# Running loss:  9.801594074815512
# Running loss windowed:  9.813240051269531
# Batch_Counter:  500
# 7 7 7
# Running loss:  9.759010799229145
# Running loss windowed:  9.681061271578074
# Batch_Counter:  550
# 4 4 4
# Running loss:  9.39164076000452
# Running loss windowed:  8.715402528643608
# Batch_Counter:  600
# 5 5 5
# Running loss:  8.907347913831472
# Running loss windowed:  9.040405172854662
# Batch_Counter:  650
# 5 5 5
# Running loss:  9.80838481336832
# Running loss windowed:  9.549228727817535
# Batch_Counter:  700
# 9 9 9
# Running loss:  9.345926813781261
# Running loss windowed:  8.83762051165104
# Batch_Counter:  750
# 4 6 4
# Running loss:  9.612124502658844
# Running loss windowed:  9.74501684308052
# Batch_Counter:  800
# 3 3 3
# Running loss:  9.348257556557655
# Running loss windowed:  9.497463576495647
# Batch_Counter:  850
# 7 7 7
# Running loss:  8.718267366290092
# Running loss windowed:  8.075005002319813
# Batch_Counter:  900
# 0 0 0
# Running loss:  8.472484111785889
# Running loss windowed:  8.066978551447392
# Epoch:  21
# Batch_Counter:  50
# 0 0 0
# Running loss:  8.75808522477746
# Running loss windowed:  8.135679334402084
# Batch_Counter:  100
# 7 7 7
# Running loss:  8.297544863075018
# Running loss windowed:  8.243644021451473
# Batch_Counter:  150
# 0 0 0
# Running loss:  9.036034308373928
# Running loss windowed:  9.257884070277214
# Batch_Counter:  200
# 9 9 9
# Running loss:  8.606506455689669
# Running loss windowed:  8.08382946997881
# Batch_Counter:  250
# 6 6 6
# Running loss:  9.894009962677956
# Running loss windowed:  9.680802308022976
# Batch_Counter:  300
# 2 2 2
# Running loss:  9.342918425798416
# Running loss windowed:  8.947665385901928
# Batch_Counter:  350
# 5 5 5
# Running loss:  9.207977198064327
# Running loss windowed:  8.992807738482952
# Batch_Counter:  400
# 8 8 8
# Running loss:  8.656071953475475
# Running loss windowed:  8.212932795286179
# Batch_Counter:  450
# 1 1 1
# Running loss:  8.879874404519796
# Running loss windowed:  8.848393507301807
# Batch_Counter:  500
# 6 6 6
# Running loss:  8.954431183636189
# Running loss windowed:  8.782697968184948
# Batch_Counter:  550
# 3 3 3
# Running loss:  8.764732141047716
# Running loss windowed:  8.43311207741499
# Batch_Counter:  600
# 1 1 1
# Running loss:  9.489797059446573
# Running loss windowed:  8.73631777614355
# Batch_Counter:  650
# 6 6 6
# Running loss:  9.4377261698246
# Running loss windowed:  9.575262695550919
# Batch_Counter:  700
# 1 1 1
# Running loss:  9.51517466828227
# Running loss windowed:  8.915624283254147
# Batch_Counter:  750
# 0 0 0
# Running loss:  9.051733512431383
# Running loss windowed:  8.291978262364864
# Batch_Counter:  800
# 4 4 4
# Running loss:  9.357882618904114
# Running loss windowed:  9.563080988824368
# Batch_Counter:  850
# 3 3 3
# Running loss:  9.476419795304537
# Running loss windowed:  9.409456506371498
# Batch_Counter:  900
# 7 7 7
# Running loss:  10.030308812856674
# Running loss windowed:  9.042057536542416
# Epoch:  22
# Batch_Counter:  50
# 6 6 6
# Running loss:  7.9764339700341225
# Running loss windowed:  8.369633540511131
# Batch_Counter:  100
# 7 7 7
# Running loss:  8.960646517574787
# Running loss windowed:  9.275116614997387
# Batch_Counter:  150
# 7 7 7
# Running loss:  8.9778773188591
# Running loss windowed:  8.979183442890644
# Batch_Counter:  200
# 0 6 0
# Running loss:  8.67574554309249
# Running loss windowed:  8.12301580235362
# Batch_Counter:  250
# 5 5 5
# Running loss:  8.6820667386055
# Running loss windowed:  8.42196036875248
# Batch_Counter:  300
# 0 6 6
# Running loss:  9.538915567100048
# Running loss windowed:  9.353698454797268
# Batch_Counter:  350
# 4 4 4
# Running loss:  9.361616961658001
# Running loss windowed:  9.036544121801853
# Batch_Counter:  400
# 4 4 4
# Running loss:  8.998062416911125
# Running loss windowed:  8.385655764490366
# Batch_Counter:  450
# 6 6 6
# Running loss:  9.75007551163435
# Running loss windowed:  9.201378978788853
# Batch_Counter:  500
# 4 4 4
# Running loss:  8.456737373024225
# Running loss windowed:  7.88288177549839
# Batch_Counter:  550
# 1 1 1
# Running loss:  9.002043176442385
# Running loss windowed:  8.67939579486847
# Batch_Counter:  600
# 7 7 7
# Running loss:  9.317750573158264
# Running loss windowed:  8.733442060649395
# Batch_Counter:  650
# 4 3 2
# Running loss:  8.534773450344801
# Running loss windowed:  8.500074058771133
# Batch_Counter:  700
# 8 8 8
# Running loss:  9.228720098733902
# Running loss windowed:  9.24479654431343
# Batch_Counter:  750
# 7 7 7
# Running loss:  8.976490899920464
# Running loss windowed:  8.997382700443268
# Batch_Counter:  800
# 6 6 6
# Running loss:  9.047269705682993
# Running loss windowed:  8.999742802232504
# Batch_Counter:  850
# 8 8 8
# Running loss:  8.611840784549713
# Running loss windowed:  8.484704583883286
# Batch_Counter:  900
# 7 7 7
# Running loss:  9.111124284565449
# Running loss windowed:  9.252536466345191
# Epoch:  23
# Batch_Counter:  50
# 8 8 8
# Running loss:  8.329227909445763
# Running loss windowed:  8.274907499551773
# Batch_Counter:  100
# 9 9 9
# Running loss:  8.273742742836475
# Running loss windowed:  8.71234229952097
# Batch_Counter:  150
# 5 5 5
# Running loss:  7.7174924723804
# Running loss windowed:  8.195335190743208
# Batch_Counter:  200
# 6 6 0
# Running loss:  8.544806871563196
# Running loss windowed:  8.303226970136166
# Batch_Counter:  250
# 5 5 5
# Running loss:  8.580646850168705
# Running loss windowed:  8.299278859049082
# Batch_Counter:  300
# 9 9 9
# Running loss:  9.409284085035324
# Running loss windowed:  8.80872893333435
# Batch_Counter:  350
# 1 1 1
# Running loss:  9.154381610453129
# Running loss windowed:  9.439805716276169
# Batch_Counter:  400
# 9 9 9
# Running loss:  8.755110323429108
# Running loss windowed:  8.38164247944951
# Batch_Counter:  450
# 4 4 4
# Running loss:  8.689749088138342
# Running loss windowed:  9.253237284719944
# Batch_Counter:  500
# 1 1 1
# Running loss:  7.776941753923893
# Running loss windowed:  8.315493643283844
# Batch_Counter:  550
# 2 2 2
# Running loss:  9.747940987348557
# Running loss windowed:  9.157208029180765
# Batch_Counter:  600
# 5 5 5
# Running loss:  8.775182269513607
# Running loss windowed:  8.369420740753412
# Batch_Counter:  650
# 4 4 4
# Running loss:  9.034559786319733
# Running loss windowed:  9.084329284727573
# Batch_Counter:  700
# 1 1 1
# Running loss:  9.359891600906849
# Running loss windowed:  9.005033120512962
# Batch_Counter:  750
# 4 4 4
# Running loss:  9.151045367121696
# Running loss windowed:  8.836302790790796
# Batch_Counter:  800
# 0 0 0
# Running loss:  8.359895631670952
# Running loss windowed:  8.164717763662338
# Batch_Counter:  850
# 7 7 7
# Running loss:  8.932819344103336
# Running loss windowed:  8.70075061172247
# Batch_Counter:  900
# 5 5 5
# Running loss:  9.41676477715373
# Running loss windowed:  9.178428940474987
# Epoch:  24
# Batch_Counter:  50
# 3 3 3
# Running loss:  8.703597471117973
# Running loss windowed:  8.318201158195734
# Batch_Counter:  100
# 4 4 4
# Running loss:  9.11001255363226
# Running loss windowed:  8.63114383071661
# Batch_Counter:  150
# 6 6 6
# Running loss:  8.174624133855104
# Running loss windowed:  7.84364777058363
# Batch_Counter:  200
# 6 6 6
# Running loss:  7.775554925203323
# Running loss windowed:  8.138974212110043
# Batch_Counter:  250
# 2 2 2
# Running loss:  8.290850080549717
# Running loss windowed:  8.413895603269339
# Batch_Counter:  300
# 5 5 5
# Running loss:  9.117946069687605
# Running loss windowed:  8.906849980354309
# Batch_Counter:  350
# 0 0 0
# Running loss:  8.425452508032322
# Running loss windowed:  8.230500221252441
# Batch_Counter:  400
# 9 9 9
# Running loss:  8.684466697275639
# Running loss windowed:  8.205085679888725
# Batch_Counter:  450
# 3 3 3
# Running loss:  9.117965169250965
# Running loss windowed:  8.970468915998936
# Batch_Counter:  500
# 5 5 5
# Running loss:  8.712644718587399
# Running loss windowed:  9.15475932508707
# Batch_Counter:  550
# 9 9 9
# Running loss:  9.434833385050297
# Running loss windowed:  9.30727718770504
# Batch_Counter:  600
# 9 9 9
# Running loss:  8.472636621445417
# Running loss windowed:  8.991528913378716
# Batch_Counter:  650
# 6 6 6
# Running loss:  8.965011544525623
# Running loss windowed:  8.7557567730546
# Batch_Counter:  700
# 0 0 6
# Running loss:  8.883257944136858
# Running loss windowed:  8.84976626187563
# Batch_Counter:  750
# 0 3 3
# Running loss:  9.208273231983185
# Running loss windowed:  8.904375202953815
# Batch_Counter:  800
# 3 3 3
# Running loss:  9.621658481657505
# Running loss windowed:  8.886687345802784
# Batch_Counter:  850
# 8 8 8
# Running loss:  9.083837814629078
# Running loss windowed:  8.894521087408066
# Batch_Counter:  900
# 8 8 8
# Running loss:  8.92069198936224
# Running loss windowed:  8.387183707207441
# Epoch:  25
# Batch_Counter:  50
# 8 8 8
# Running loss:  8.893544785678387
# Running loss windowed:  8.59442812204361
# Batch_Counter:  100
# 6 6 6
# Running loss:  8.089708250015974
# Running loss windowed:  7.9137528240680695
# Batch_Counter:  150
# 7 7 7
# Running loss:  8.169791467487812
# Running loss windowed:  8.446368217468262
# Batch_Counter:  200
# 9 9 9
# Running loss:  8.023524846881628
# Running loss windowed:  7.862300291657448
# Batch_Counter:  250
# 8 8 8
# Running loss:  8.542383965104818
# Running loss windowed:  8.222364034503698
# Batch_Counter:  300
# 7 7 7
# Running loss:  8.671110309660435
# Running loss windowed:  8.524344123899937
# Batch_Counter:  350
# 7 7 7
# Running loss:  8.19578641653061
# Running loss windowed:  7.985151585191488
# Batch_Counter:  400
# 5 5 5
# Running loss:  8.347112871706486
# Running loss windowed:  8.461285032331944
# Batch_Counter:  450
# 9 9 9
# Running loss:  8.226976376026869
# Running loss windowed:  7.986021444201469
# Batch_Counter:  500
# 7 7 7
# Running loss:  8.131041146814823
# Running loss windowed:  7.989840969443321
# Batch_Counter:  550
# 9 9 9
# Running loss:  8.368104312568903
# Running loss windowed:  7.981779627501965
# Batch_Counter:  600
# 6 2 6
# Running loss:  8.295429669320583
# Running loss windowed:  8.42497480660677
# Batch_Counter:  650
# 1 1 1
# Running loss:  8.739817012101412
# Running loss windowed:  9.13063509017229
# Batch_Counter:  700
# 3 3 3
# Running loss:  8.728141441941261
# Running loss windowed:  9.023610077798367
# Batch_Counter:  750
# 8 8 8
# Running loss:  9.264390114694834
# Running loss windowed:  9.556731428951025
# Batch_Counter:  800
# 9 9 9
# Running loss:  9.364333786070347
# Running loss windowed:  9.296932369470596
# Batch_Counter:  850
# 3 3 3
# Running loss:  8.818945959210396
# Running loss windowed:  8.824904911220074
# Batch_Counter:  900
# 4 4 4
# Running loss:  8.95630645006895
# Running loss windowed:  8.48369124904275
# Epoch:  26
# Batch_Counter:  50
# 7 7 7
# Running loss:  7.469459384679794
# Running loss windowed:  7.936214424669743
# Batch_Counter:  100
# ...
# Running loss windowed:  7.876824855804443
# Batch_Counter:  500
# 0 0 0
# Running loss:  6.0801772847771645
# Running loss windowed:  6.503170378506184
# Batch_Counter:  550
# 7 7 7
# Running loss:  6.726847253739834
# Running loss windowed:  7.33663672208786
# Batch_Counter:  600
# 4 4 4
# Running loss:  6.655652388930321
# Running loss windowed:  6.885930959135294
# Batch_Counter:  650
# 2 2 2
# Running loss:  7.385584726929665
# Running loss windowed:  7.564259618520737
# Batch_Counter:  700
# 3 3 3
# Running loss:  7.850612446665764
# Running loss windowed:  8.572843350470066
# Batch_Counter:  750
# 6 4 4
# Running loss:  6.716252809390426
# Running loss windowed:  7.62514198385179
# Batch_Counter:  800
# 4 4 4
# Running loss:  8.92197921127081
# Running loss windowed:  8.502279505133629
# Batch_Counter:  850
# 8 8 8
# Running loss:  7.493372447788715
# Running loss windowed:  8.532767377793789
# Batch_Counter:  900
# 7 7 7
# Running loss:  7.455414406955242
# Running loss windowed:  7.843069843947887
# Epoch:  42
# Batch_Counter:  50
# 1 1 1
# Running loss:  6.316434508189559
# Running loss windowed:  6.733398862183094
# Batch_Counter:  100
# 2 2 2
# Running loss:  5.927364710718393
# Running loss windowed:  6.2632798701524734
# Batch_Counter:  150
# 2 4 4
# Running loss:  7.115638393908739
# Running loss windowed:  7.134927526116371
# Batch_Counter:  200
# 1 1 1
# Running loss:  6.921976327896118
# Running loss windowed:  7.013482976704836
# Batch_Counter:  250
# 2 2 2
# Running loss:  6.758596006780863
# Running loss windowed:  7.216038558632135
# Batch_Counter:  300
# 1 1 1
# Running loss:  6.757289929315448
# Running loss windowed:  6.970751658082008
# Batch_Counter:  350
# 4 4 4
# Running loss:  7.6001812145113945
# Running loss windowed:  7.407634899020195
# Batch_Counter:  400
# 7 7 7
# Running loss:  6.839141454547644
# Running loss windowed:  7.499754901975393
# Batch_Counter:  450
# 8 8 8
# Running loss:  6.072655327618122
# Running loss windowed:  6.989976271986961
# Batch_Counter:  500
# 6 6 6
# Running loss:  7.145498478785157
# Running loss windowed:  8.119661595672369
# Batch_Counter:  550
# 9 9 9
# Running loss:  6.302835620939732
# Running loss windowed:  6.7167238891124725
# Batch_Counter:  600
# 1 1 1
# Running loss:  6.667675212025642
# Running loss windowed:  7.833111330866814
# Batch_Counter:  650
# 1 1 1
# Running loss:  6.976186435669661
# Running loss windowed:  7.070906553417444
# Batch_Counter:  700
# 0 0 2
# Running loss:  7.973738994449377
# Running loss windowed:  8.350651741027832
# Batch_Counter:  750
# 4 4 4
# Running loss:  7.41214120388031
# Running loss windowed:  7.723223526030779
# Batch_Counter:  800
# 2 2 2
# Running loss:  7.905096244066954
# Running loss windowed:  8.44799005240202
# Batch_Counter:  850
# 1 1 1
# Running loss:  7.124125212430954
# Running loss windowed:  7.8694684617221355
# Batch_Counter:  900
# 7 7 7
# Running loss:  7.46653263643384
# Running loss windowed:  7.8224747478961945
# Epoch:  43
# Batch_Counter:  50
# 0 0 0
# Running loss:  5.671666394919157
# Running loss windowed:  6.8598568215966225
# Batch_Counter:  100
# 6 0 6
# Running loss:  6.521584078669548
# Running loss windowed:  6.986271038651466
# Batch_Counter:  150
# 4 4 4
# Running loss:  5.705119106918573
# Running loss windowed:  6.383106902241707
# Batch_Counter:  200
# 3 3 3
# Running loss:  6.134547419846058
# Running loss windowed:  6.768094960600138
# Batch_Counter:  250
# 2 4 4
# Running loss:  7.27935148589313
# Running loss windowed:  7.628034666180611
# Batch_Counter:  300
# 8 8 8
# Running loss:  7.036374939605594
# Running loss windowed:  7.662046015262604
# Batch_Counter:  350
# 6 6 6
# Running loss:  7.35597563162446
# Running loss windowed:  7.671144090592861
# Batch_Counter:  400
# 2 2 2
# Running loss:  6.915610086172819
# Running loss windowed:  7.573271527886391
# Batch_Counter:  450
# 9 9 9
# Running loss:  6.947527300566435
# Running loss windowed:  7.786910869181156
# Batch_Counter:  500
# 4 4 4
# Running loss:  7.833165962249041
# Running loss windowed:  8.39602643251419
# Batch_Counter:  550
# 5 5 5
# Running loss:  6.613451912999153
# Running loss windowed:  7.887789763510227
# Batch_Counter:  600
# 3 3 3
# Running loss:  7.045403454452753
# Running loss windowed:  7.03053118288517
# Batch_Counter:  650
# 0 0 0
# Running loss:  7.018864147365093
# Running loss windowed:  7.158053319901228
# Batch_Counter:  700
# 5 5 5
# Running loss:  7.470791418105364
# Running loss windowed:  7.8732802495360374
# Batch_Counter:  750
# 4 4 4
# Running loss:  7.757690995931625
# Running loss windowed:  8.273680951446295
# Batch_Counter:  800
# 6 6 6
# Running loss:  7.096970807760954
# Running loss windowed:  6.870279785245657
# Batch_Counter:  850
# 8 8 8
# Running loss:  6.852245781570673
# Running loss windowed:  7.426010780036449
# Batch_Counter:  900
# 5 5 5
# Running loss:  7.959680020809174
# Running loss windowed:  8.063972819596529
# Epoch:  44
# Batch_Counter:  50
# 9 9 9
# Running loss:  6.012572834268212
# Running loss windowed:  6.636379510164261
# Batch_Counter:  100
# 1 1 1
# Running loss:  5.773954421281815
# Running loss windowed:  6.504157979041338
# Batch_Counter:  150
# 4 4 4
# Running loss:  6.427699079737067
# Running loss windowed:  6.498700197786093
# Batch_Counter:  200
# 9 9 9
# Running loss:  7.547807615250349
# Running loss windowed:  7.509014518931508
# Batch_Counter:  250
# 9 9 9
# Running loss:  6.154109034687281
# Running loss windowed:  6.872703488916159
# Batch_Counter:  300
# 9 9 9
# Running loss:  6.757191978394985
# Running loss windowed:  7.522114749997854
# Batch_Counter:  350
# 7 7 7
# Running loss:  6.224113389849663
# Running loss windowed:  6.878814961761236
# Batch_Counter:  400
# 4 4 4
# Running loss:  6.885505333542824
# Running loss windowed:  7.780091445893049
# Batch_Counter:  450
# 3 3 3
# Running loss:  7.210618142038584
# Running loss windowed:  7.4904785715043545
# Batch_Counter:  500
# 4 4 4
# Running loss:  7.591200198978186
# Running loss windowed:  8.38221450895071
# Batch_Counter:  550
# 0 0 0
# Running loss:  7.695114366710186
# Running loss windowed:  7.887499131262302
# Batch_Counter:  600
# 0 0 0
# Running loss:  7.20922551676631
# Running loss windowed:  7.333715662360191
# Batch_Counter:  650
# 3 3 3
# Running loss:  6.741403244435787
# Running loss windowed:  7.3847590908408165
# Batch_Counter:  700
# 0 6 6
# Running loss:  7.906599156558514
# Running loss windowed:  7.437285915017128
# Batch_Counter:  750
# 4 4 4
# Running loss:  7.076011586934328
# Running loss windowed:  8.106636296957731
# Batch_Counter:  800
# 3 3 3
# Running loss:  6.863420959562063
# Running loss windowed:  6.979769058525562
# Batch_Counter:  850
# 2 2 2
# Running loss:  7.652248077094555
# Running loss windowed:  7.664176873862743
# Batch_Counter:  900
# 7 7 7
# Running loss:  6.547005109488964
# Running loss windowed:  7.306059002876282
# Epoch:  45
# Batch_Counter:  50
# 1 1 1
# Running loss:  5.865500673651695
# Running loss windowed:  5.914086394011974
# Batch_Counter:  100
# 0 2 0
# Running loss:  5.9292332753539085
# Running loss windowed:  6.498903062194586
# Batch_Counter:  150
# 4 4 4
# Running loss:  5.986541699618101
# Running loss windowed:  6.684185955673456
# Batch_Counter:  200
# 4 4 4
# Running loss:  7.512004405260086
# Running loss windowed:  7.093251559883356
# Batch_Counter:  250
# 5 5 5
# Running loss:  6.240532107651234
# Running loss windowed:  7.012630932033062
# Batch_Counter:  300
# 0 6 0
# Running loss:  6.565449338406324
# Running loss windowed:  7.588112078607082
# Batch_Counter:  350
# 4 4 4
# Running loss:  7.00627089291811
# Running loss windowed:  7.10691124945879
# Batch_Counter:  400
# 1 1 1
# Running loss:  6.816542107611895
# Running loss windowed:  7.406188897788525
# Batch_Counter:  450
# 9 9 9
# Running loss:  6.618421141058207
# Running loss windowed:  7.463158093392849
# Batch_Counter:  500
# 0 0 0
# Running loss:  7.287441730499268
# Running loss windowed:  7.818121075630188
# Batch_Counter:  550
# 3 3 3
# Running loss:  6.97497820854187
# Running loss windowed:  7.72999132797122
# Batch_Counter:  600
# 1 1 1
# Running loss:  6.491239711642265
# Running loss windowed:  7.377787955105305
# Batch_Counter:  650
# 6 6 6
# Running loss:  7.81120166182518
# Running loss windowed:  7.972726970911026
# Batch_Counter:  700
# 9 9 9
# Running loss:  7.9120073318481445
# Running loss windowed:  7.922007121145725
# Batch_Counter:  750
# 9 9 9
# Running loss:  6.483242601156235
# Running loss windowed:  6.991562303155661
# Batch_Counter:  800
# 6 6 6
# Running loss:  7.711183305829763
# Running loss windowed:  8.00954369455576
# Batch_Counter:  850
# 5 5 5
# Running loss:  6.358659071847796
# Running loss windowed:  6.623826451599598
# Batch_Counter:  900
# 4 4 4
# Running loss:  6.959262616932392
# Running loss windowed:  7.302500419318676
# Epoch:  46
# Batch_Counter:  50
# 5 5 5
# Running loss:  6.215011291205883
# Running loss windowed:  6.580406945198774
# Batch_Counter:  100
# 4 4 4
# Running loss:  5.481235830113292
# Running loss windowed:  6.548207487910986
# Batch_Counter:  150
# 5 5 5
# Running loss:  6.480391716584563
# Running loss windowed:  7.257602233439684
# Batch_Counter:  200
# 7 7 7
# Running loss:  6.532252622768283
# Running loss windowed:  7.8381989896297455
# Batch_Counter:  250
# 0 0 0
# Running loss:  6.431744895875454
# Running loss windowed:  7.050476770848036
# Batch_Counter:  300
# 1 1 1
# Running loss:  6.705608081072569
# Running loss windowed:  7.586899481713772
# Batch_Counter:  350
# 9 9 9
# Running loss:  6.898254971951246
# Running loss windowed:  7.673225428909063
# Batch_Counter:  400
# 5 5 5
# Running loss:  6.866094775497913
# Running loss windowed:  7.4376350194215775
# Batch_Counter:  450
# 7 7 7
# Running loss:  7.696368783712387
# Running loss windowed:  7.79530818015337
# Batch_Counter:  500
# 7 7 7
# Running loss:  6.55492839962244
# Running loss windowed:  7.82426493614912
# Batch_Counter:  550
# 4 4 4
# Running loss:  6.98242574557662
# Running loss windowed:  7.764058604836464
# Batch_Counter:  600
# 1 1 1
# Running loss:  7.921302683651447
# Running loss windowed:  8.507264964282513
# Batch_Counter:  650
# 4 4 4
# Running loss:  7.28918669000268
# Running loss windowed:  7.4363899156451225
# Batch_Counter:  700
# 9 9 9
# Running loss:  6.660249829292297
# Running loss windowed:  7.310502093285322
# Batch_Counter:  750
# 7 7 7
# Running loss:  6.153669524937868
# Running loss windowed:  7.1704785861074924
# Batch_Counter:  800
# 8 8 8
# Running loss:  6.6251961551606655
# Running loss windowed:  7.358593463897705
# Batch_Counter:  850
# 2 2 2
# Running loss:  7.517748616635799
# Running loss windowed:  7.658425018191338
# Batch_Counter:  900
# 2 2 2
# Running loss:  7.464844889938831
# Running loss windowed:  7.2266792841255665
# Epoch:  47
# Batch_Counter:  50
# 4 4 4
# Running loss:  6.76476875692606
# Running loss windowed:  7.185783933848143
# Batch_Counter:  100
# 8 8 8
# Running loss:  5.11263145506382
# Running loss windowed:  6.12708704918623
# Batch_Counter:  150
# 6 6 6
# Running loss:  5.825432490557432
# Running loss windowed:  6.3577314261347055
# Batch_Counter:  200
# 9 9 9
# Running loss:  6.843531642109156
# Running loss windowed:  7.902540139853954
# Batch_Counter:  250
# 4 4 4
# Running loss:  5.99051277898252
# Running loss windowed:  7.719669137150049
# Batch_Counter:  300
# 2 3 2
# Running loss:  6.099350243806839
# Running loss windowed:  7.326727163046598
# Batch_Counter:  350
# 6 6 6
# Running loss:  6.435438629239798
# Running loss windowed:  7.091870740056038
# Batch_Counter:  400
# 3 3 3
# Running loss:  6.41112801246345
# Running loss windowed:  6.832056351006031
# Batch_Counter:  450
# 7 7 7
# Running loss:  7.539897285401821
# Running loss windowed:  7.277729023247957
# Batch_Counter:  500
# 9 9 9
# Running loss:  7.189513769000769
# Running loss windowed:  8.053521297872066
# Batch_Counter:  550
# 2 2 2
# Running loss:  6.497337080538273
# Running loss windowed:  7.3093215227127075
# Batch_Counter:  600
# 5 5 5
# Running loss:  6.819770686328411
# Running loss windowed:  7.188948079943657
# Batch_Counter:  650
# 8 8 8
# Running loss:  6.863446936011314
# Running loss windowed:  7.476465113461018
# Batch_Counter:  700
# 4 4 4
# Running loss:  6.19437850266695
# Running loss windowed:  6.96261334978044
# Batch_Counter:  750
# 0 0 0
# Running loss:  7.477060709148645
# Running loss windowed:  6.850353054702282
# Batch_Counter:  800
# 0 0 0
# Running loss:  6.660688038915396
# Running loss windowed:  7.777953650802374
# Batch_Counter:  850
# 5 5 5
# Running loss:  7.778654560446739
# Running loss windowed:  7.877736657857895
# Batch_Counter:  900
# 6 6 6
# Running loss:  7.458513602614403
# Running loss windowed:  7.789541684091091
# Epoch:  48
# Batch_Counter:  50
# 1 1 1
# Running loss:  6.167666789144278
# Running loss windowed:  6.233730163425207
# Batch_Counter:  100
# 9 9 9
# Running loss:  5.83765721321106
# Running loss windowed:  7.08130007982254
# Batch_Counter:  150
# 1 1 1
# Running loss:  6.055404085665941
# Running loss windowed:  6.4815913662314415
# Batch_Counter:  200
# 7 7 7
# Running loss:  6.227559790015221
# Running loss windowed:  6.285394053906202
# Batch_Counter:  250
# 5 5 5
# Running loss:  6.791140429675579
# Running loss windowed:  7.172979645431042
# Batch_Counter:  300
# 1 1 1
# Running loss:  6.408123072236776
# Running loss windowed:  7.013806261122227
# Batch_Counter:  350
# 4 4 4
# Running loss:  6.215968215838075
# Running loss windowed:  7.300612326711416
# Batch_Counter:  400
# 9 9 9
# Running loss:  5.779965464025736
# Running loss windowed:  7.064625006169081
# Batch_Counter:  450
# 5 5 5
# Running loss:  7.215262588113546
# Running loss windowed:  7.68676445633173
# Batch_Counter:  500
# 9 9 9
# Running loss:  6.4266549833118916
# Running loss windowed:  6.661172371357679
# Batch_Counter:  550
# 2 2 2
# Running loss:  6.037417471408844
# Running loss windowed:  6.407522805035114
# Batch_Counter:  600
# 7 7 7
# Running loss:  6.881694063544273
# Running loss windowed:  6.97157846018672
# Batch_Counter:  650
# 2 2 2
# Running loss:  7.516384892165661
# Running loss windowed:  8.122160162776709
# Batch_Counter:  700
# 8 8 8
# Running loss:  6.580434400588274
# Running loss windowed:  6.690409384667873
# Batch_Counter:  750
# 6 6 6
# Running loss:  7.318355578929186
# Running loss windowed:  8.122020618990064
# Batch_Counter:  800
# 4 4 3
# Running loss:  7.060671424493194
# Running loss windowed:  7.847006421536207
# Batch_Counter:  850
# 0 0 0
# Running loss:  7.035749260336161
# Running loss windowed:  7.595726795494556
# Batch_Counter:  900
# 5 5 5
# Running loss:  7.913716647773981
# Running loss windowed:  8.037701074033976
# Epoch:  49
# Batch_Counter:  50
# 9 9 9
# Running loss:  6.310156986117363
# Running loss windowed:  7.634485136717558
# Batch_Counter:  100
# 2 2 2
# Running loss:  6.632162053138018
# Running loss windowed:  7.3253788985311985
# Batch_Counter:  150
# 3 3 3
# Running loss:  5.866084113717079
# Running loss windowed:  6.336459323763847
# Batch_Counter:  200
# 2 2 2
# Running loss:  5.616765286773443
# Running loss windowed:  6.624855048954487
# Batch_Counter:  250
# 1 1 1
# Running loss:  6.323572197929025
# Running loss windowed:  6.635113807395101
# Batch_Counter:  300
# 5 5 5
# Running loss:  5.791933864355087
# Running loss windowed:  6.036376681178808
# Batch_Counter:  350
# 6 6 6
# Running loss:  6.997939709573984
# Running loss windowed:  7.492451585829258
# Batch_Counter:  400
# 7 7 7
# Running loss:  6.436488250270486
# Running loss windowed:  6.945601396262646
# Batch_Counter:  450
# 2 2 2
# Running loss:  7.23893803358078
# Running loss windowed:  7.943182148039341
# Batch_Counter:  500
# 0 0 0
# Running loss:  5.9415318332612514
# Running loss windowed:  7.001208025962114
# Batch_Counter:  550
# 8 8 8
# Running loss:  6.549337089061737
# Running loss windowed:  6.808408290147781
# Batch_Counter:  600
# 6 6 0
# Running loss:  6.852031324058771
# Running loss windowed:  6.971623510122299
# Batch_Counter:  650
# 3 3 3
# Running loss:  6.453407399356365
# Running loss windowed:  7.182073246687651
# Batch_Counter:  700
# 7 7 7
# Running loss:  7.190188329666853
# Running loss windowed:  7.782229024916887
# Batch_Counter:  750
# 7 7 7
# Running loss:  6.979105703532696
# Running loss windowed:  7.536676928400993
# Batch_Counter:  800
# 1 1 1
# Running loss:  6.141468621790409
# Running loss windowed:  6.044456019997597
# Batch_Counter:  850
# 6 6 6
# Running loss:  7.4215355180203915
# Running loss windowed:  7.2736112885177135
# Batch_Counter:  900
# 3 3 3
# Running loss:  6.5095509365201
# Running loss windowed:  7.160262670367956
# Validating...
# Batch_Counter:  20
# Batch_Counter:  40
# Batch_Counter:  60
# Batch_Counter:  80
# Batch_Counter:  100
# Batch_Counter:  120
# Batch_Counter:  140
# Accuracy:  [793. 989. 825. 896. 944. 995. 762. 977. 984. 962.]
# Accuracy_Win:  [849. 993. 888. 919. 922. 990. 802. 948. 994. 982.]
# class_counter:  [1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000.]
# Accuracy_percentage:  91.27
# Accuracy_win_percentage:  92.86999999999999
