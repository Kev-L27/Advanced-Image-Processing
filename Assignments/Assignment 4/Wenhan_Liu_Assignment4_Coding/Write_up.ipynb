# %% [markdown]
# For task 1 implementing your_model, I first used only 3 convolutional layers along with 3 maxpooling layers, one drop out layer, one flatten layer and 2 dense layers with a structure like this:
#
# ![11.png](data:image/png;base64,...)
#
# But for this structure, the result was rather bad, the val_sparse_categorial_accuracy could not even reach 60%.
#
# So then I'm thinking of adding more layers to make the network deeper, and I also reduced one dense layer, as it could increased the number of parameters dramatically, which is not what I want. With a structure like this:
#
# ![image.png](data:image/png;base64,...)
#
# The network was able to achieve 66% test accuracy.
#
# Seeing the benefits of adding more layers, I just wanted to try for the last time to make the network even deeper and see if it could have any better results. And with a structure like this:
#
# ![image.png](data:image/png;base64,...)
#
# The test accuracy got worse than before, and it didn't even reach 65% test accuracy, which is not what I expected.

# %% [markdown]
# So, as a result, I eventually used this structure for your_model, and the final test accuracy it could achieve is 66.13%.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)
#
# And the model summary is as follows:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As for task 2, the VGG model, I just used one conv layer followed by a maxpooling layer, one flatten layer and one dense layer the first time with a structure like this:
#
# ![image.png](data:image/png;base64,...)
#
# And the result just passed the first time, which is surprisingly efficient. And the final test accurcy it achieved is: 87.57%
#
# ![image.png](data:image/png;base64,...)
#
# And here's the model summary:
#
# ![image.png](data:image/png;base64,...)
